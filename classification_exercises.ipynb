# %%
import numpy as np
import pandas as pd
from pydataset import data

# %% [markdown]
# Create a pandas dataframe, df_iris

# %%
df_iris = data('iris')

# %% [markdown]
# print the first 3 rows

# %% [markdown]
# d

# %%
df_iris.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# print the number of rows and columns (shape)

# %%
df_iris.shape
# Out:
# (150, 5)

# %% [markdown]
# print the column names

# %%
list(df_iris.columns.values)
# Out:
# ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species']

# %% [markdown]
# print the data type of each column

# %%
df_iris.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %% [markdown]
# print the summary statistics for each of the numeric variables

# %%
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'
csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')
df_google = pd.read_csv(csv_export_url)

# %% [markdown]
# print the first 3 rows

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# print the number of rows and columns

# %%
df_google.shape
# Out:
# (891, 12)

# %% [markdown]
# print the column names

# %%
list(df_google.columns.values)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# print the data type of each column

# %%
df_google.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# print the summary statistics for each of the numeric variables

# %%
df_google[['Age','Fare','SibSp','Parch']].describe()
# Out:
#               Age        Fare       SibSp       Parch
# count  714.000000  891.000000  891.000000  891.000000
# mean    29.699118   32.204208    0.523008    0.381594
# std     14.526497   49.693429    1.102743    0.806057
# min      0.420000    0.000000    0.000000    0.000000
# 25%     20.125000    7.910400    0.000000    0.000000
# 50%     28.000000   14.454200    0.000000    0.000000
# 75%     38.000000   31.000000    1.000000    0.000000
# max     80.000000  512.329200    8.000000    6.000000

# %% [markdown]
# print the unique values for each of your categorical variables

# %%
df_google[['Survived','Pclass','Sex','Embarked']].apply(lambda x: x.unique())
# Out:
# Survived            [0, 1]
# Pclass           [3, 1, 2]
# Sex         [male, female]
# Embarked    [S, C, Q, nan]
# dtype: object

# %%
df_excel = pd.read_excel('train.xlsx')

# %% [markdown]
# assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel_sample = df_excel.head(100)

# %% [markdown]
# print the number of rows of your original dataframe

# %%
df_excel.shape[0]
# Out:
# 891

# %% [markdown]
# print the first 5 column names

# %%
df_excel.columns[:5]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'], dtype='object')

# %% [markdown]
# print the column names that have a data type of object

# %%
list(df_excel.select_dtypes('object').columns)
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# compute the range for each of the numeric variables.

# %%
df_excel.select_dtypes(['int64','float64']).apply(lambda x: x.max() - x.min(),axis=0)
# Out:
# PassengerId    890.0000
# Survived         1.0000
# Pclass           2.0000
# Age             79.5800
# SibSp            8.0000
# Parch            6.0000
# Fare           512.3292
# dtype: float64

# %% [markdown]
# # Prepare the data

# %%
from acquire import get_iris_data
from prepare import prep_iris
iris_df = get_iris_data()
iris_train,iris_test,iris_split = prep_iris(iris_df)
iris_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 79            5.7          2.6           3.5          1.0  versicolor
# 36            5.5          3.5           1.3          0.2      setosa
# 133           6.3          2.8           5.1          1.5   virginica
# 95            5.7          3.0           4.2          1.2  versicolor
# 18            5.7          3.8           1.7          0.3      setosa
#
#      species_setosa  species_versicolor  species_virginica
# 79                0                   1                  0
# 36                1                   0                  0
# 133               0                   0                  1
# 95                0                   1                  0
# 18                1                   0                  0

# %%
from acquire import get_titanic_data
from prepare import prep_titanic
titanic_df = get_titanic_data()
titanic_train, titanic_validate, titanic_test = prep_titanic(titanic_df)

# %%
import numpy as np
import pandas as pd
from pydataset import data

# %%
from acquire import get_telco_data
from prepare import prep_telco
telco_df = get_telco_data()
# telco_df = prep_telco(telco_df)
telco_df.head().transpose()
# Out:
#                                      0               1                 2  \
# payment_type_id                      2               2                 1
# internet_service_type_id             1               1                 2
# contract_type_id                     2               1                 1
# customer_id                 0002-ORFBO      0003-MKNFE        0004-TLHLJ
# gender                          Female            Male              Male
# senior_citizen                       0               0                 0
# partner                            Yes              No                No
# dependents                         Yes              No                No
# tenure                               9               9                 4
# phone_service                      Yes             Yes               Yes
# multiple_lines                      No             Yes                No
# online_security                     No              No                No
# online_backup                      Yes              No                No
# device_protection                   No              No               Yes
# tech_support                       Yes              No                No
# streaming_tv                       Yes              No                No
# streaming_movies                    No             Yes                No
# paperless_billing                  Yes              No               Yes
# monthly_charges                   65.6            59.9              73.9
# total_charges                    593.3           542.4            280.85
# churn                               No              No               Yes
# contract_type                 One year  Month-to-month    Month-to-month
# internet_service_type              DSL             DSL       Fiber optic
# payment_type              Mailed check    Mailed check  Electronic check
#
#                                          3               4
# payment_type_id                          1               2
# internet_service_type_id                 2               2
# contract_type_id                         1               1
# customer_id                     0011-IGKFF      0013-EXCHZ
# gender                                Male          Female
# senior_citizen                           1               1
# partner                                Yes             Yes
# dependents                              No              No
# tenure                                  13               3
# phone_service                          Yes             Yes
# multiple_lines                          No              No
# online_security                         No              No
# online_backup                          Yes              No
# device_protection                      Yes              No
# tech_support                            No             Yes
# streaming_tv                           Yes             Yes
# streaming_movies                       Yes              No
# paperless_billing                      Yes             Yes
# monthly_charges                       98.0            83.9
# total_charges                      1237.85           267.4
# churn                                  Yes             Yes
# contract_type               Month-to-month  Month-to-month
# internet_service_type          Fiber optic     Fiber optic
# payment_type              Electronic check    Mailed check

# %% [markdown]
# ## Exercises
#
# ### Part 1
#
# Continue in your `classification_exercises.ipynb` notebook. As always, add, commit, and push your changes.
#
# **Section 1 - iris_db:** Using iris data from our mySQL server and the methods used in the lesson above:
#
# 1. Acquire, prepare & split your data.

# %% [markdown]
# 1. Univariate Stats
#
#     - For each measurement type (quantitative variable): create a histogram, boxplot, & compute descriptive statistics (using .describe()).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
iris_quantitative = iris_train[['sepal_length','sepal_width','petal_length','petal_width']]
plt.figure(figsize=(12,4))
plt.subplot(121)
sns.boxplot(data=iris_quantitative,x='sepal_length')
plt.subplot(122)
sns.histplot(data=iris_quantitative,x='sepal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %% [markdown]
# ## Takeaways
# - sepal-length is relatively normally distributed with no outliers

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
sns.boxplot(data=iris_quantitative,x='sepal_width')
plt.subplot(122)
sns.histplot(data=iris_quantitative,x='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
sns.boxplot(data=iris_quantitative,x='petal_width')
plt.subplot(122)
sns.histplot(data=iris_quantitative,x='petal_width')
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='Count'>

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
sns.boxplot(data=iris_quantitative,x='petal_length')
plt.subplot(122)
sns.histplot(data=iris_quantitative,x='petal_length')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
iris_train.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  species_setosa  \
# count     84.000000    84.000000     84.000000    84.000000       84.000000
# mean       5.870238     3.075000      3.771429     1.203571        0.333333
# std        0.769099     0.448256      1.734940     0.752577        0.474236
# min        4.400000     2.200000      1.200000     0.100000        0.000000
# 25%        5.375000     2.800000      1.600000     0.400000        0.000000
# 50%        5.800000     3.000000      4.250000     1.300000        0.000000
# 75%        6.400000     3.400000      5.100000     1.800000        1.000000
# max        7.900000     4.400000      6.900000     2.500000        1.000000
#
#        species_versicolor  species_virginica
# count           84.000000          84.000000
# mean             0.333333           0.333333
# std              0.474236           0.474236
# min              0.000000           0.000000
# 25%              0.000000           0.000000
# 50%              0.000000           0.000000
# 75%              1.000000           1.000000
# max              1.000000           1.000000

# %% [markdown]
#     - For each species (categorical variable): create a frequency table and a bar plot of those frequencies.

# %%
iris_train.species.value_counts()
# Out:
# versicolor    28
# setosa        28
# virginica     28
# Name: species, dtype: int64

# %%
species_vc = iris_train.species.value_counts()
sns.barplot(x=species_vc.index,y=species_vc.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 2. Bivariate Stats
#
#     - Visualize each measurement type (y-axis) with the species variable (x-axis) using barplots, adding a horizontal line showing the overall mean of the metric (y-axis).

# %%
plt.figure(figsize=(12,12))
plt.subplot(221)
graph = sns.barplot(data=iris_train, x='species',y='sepal_length')
graph.axhline(iris_train.sepal_length.mean())
plt.subplot(222)
graph = sns.barplot(data=iris_train, x='species',y='sepal_width')
graph.axhline(iris_train.sepal_width.mean())
plt.subplot(223)
graph = sns.barplot(data=iris_train, x='species',y='petal_length')
graph.axhline(iris_train.petal_length.mean())
plt.subplot(224)
graph = sns.barplot(data=iris_train, x='species',y='petal_width')
graph.axhline(iris_train.petal_width.mean())

# %% [markdown]
#     - For each measurement type, compute the descriptive statistics for each species.

# %%
versicolor = iris_train[iris_train.species_versicolor==1][['sepal_length','sepal_width','petal_length','petal_width']]
virginica = iris_train[iris_train.species_virginica==1][['sepal_length','sepal_width','petal_length','petal_width']]
setosa = iris_train[iris_train.species_setosa==1][['sepal_length','sepal_width','petal_length','petal_width']]
indices = pd.MultiIndex.from_product([['versicolor','virginica','setosa'],['sepal_length','sepal_width','petal_length','petal_width']])
concat_frames = pd.concat([versicolor,virginica,setosa],axis=1)
concat_frames.columns = indices
concat_frames.describe()
# Out:
#         versicolor                                         virginica  \
#       sepal_length sepal_width petal_length petal_width sepal_length
# count    28.000000   28.000000    28.000000   28.000000    28.000000
# mean      5.896429    2.796429     4.271429    1.314286     6.625000
# std       0.425556    0.280848     0.409930    0.199470     0.532378
# min       4.900000    2.300000     3.300000    1.000000     5.800000
# 25%       5.600000    2.600000     4.000000    1.200000     6.300000
# 50%       5.800000    2.800000     4.250000    1.300000     6.450000
# 75%       6.125000    3.000000     4.525000    1.500000     6.900000
# max       6.900000    3.400000     5.100000    1.800000     7.900000
#
#                                                  setosa              \
#       sepal_width petal_length petal_width sepal_length sepal_width
# count   28.000000    28.000000   28.000000    28.000000   28.000000
# mean     2.960714     5.535714    2.021429     5.089286    3.467857
# std      0.318956     0.496815    0.293582     0.360390    0.427788
# min      2.200000     4.800000    1.500000     4.400000    2.300000
# 25%      2.800000     5.100000    1.800000     4.875000    3.275000
# 50%      3.000000     5.500000    2.000000     5.000000    3.400000
# 75%      3.100000     5.800000    2.300000     5.400000    3.800000
# max      3.800000     6.900000    2.500000     5.800000    4.400000
#
#
#       petal_length petal_width
# count    28.000000    28.00000
# mean      1.507143     0.27500
# std       0.184448     0.12057
# min       1.200000     0.10000
# 25%       1.400000     0.20000
# 50%       1.500000     0.20000
# 75%       1.600000     0.40000
# max       1.900000     0.60000

# %% [markdown]
#     - For virginica & versicolor: Compare the mean petal_width using the Mann-Whitney test (scipy.stats.mannwhitneyu) to see if there is a significant difference between the two groups. Do the same for the other measurement types.

# %%
from scipy.stats import mannwhitneyu
t,p = mannwhitneyu(virginica.sepal_length,versicolor.sepal_length)
t,p
# Out:
# (676.5, 3.082029196534108e-06)

# %%
from scipy.stats import mannwhitneyu
t,p = mannwhitneyu(virginica.sepal_width,versicolor.sepal_width)
t,p
# Out:
# (510.0, 0.05257259139845694)

# %%
from scipy.stats import mannwhitneyu
t,p = mannwhitneyu(virginica.petal_width,versicolor.petal_width)
t,p
# Out:
# (767.0, 6.47119166980993e-10)

# %%
from scipy.stats import mannwhitneyu
t,p = mannwhitneyu(virginica.petal_length,versicolor.petal_length)
t,p
# Out:
# (776.5, 2.9479835715150625e-10)

# %% [markdown]
#     - Document takeaways & any actions.
# Sepal is not a good predictive value for species
#
# 3. Multivariate Stats
#
#     - Visualize the interaction of each measurement type with the others using a pairplot (or scatter matrix or something similar) and add color to represent species.

# %%
sns.pairplot(data=iris_train[['species','sepal_length','sepal_width','petal_length','petal_width']],hue='species',corner=True)

# %% [markdown]
#     - Visualize two numeric variables by means of the species. Hint: `sns.relplot` with `hue` or `col`

# %%
sns.relplot(data=iris_train,x='petal_length',y='petal_width',hue='species')

# %% [markdown]
#     - Create a swarmplot using a melted dataframe of all your numeric variables. The x-axis should be the variable name, the y-axis the measure. Add another dimension using color to represent species. Document takeaways from this visualization.

# %%
plt.figure(figsize=(8,8))
iris_melt = iris_train[['species','sepal_length','sepal_width','petal_length','petal_width']].melt(id_vars='species')
iris_melt.head()
sns.swarmplot(data=iris_melt,x='variable',y='value',hue='species')
# Out:
# <AxesSubplot:xlabel='variable', ylabel='value'>

# %% [markdown]
#     - Ask a specific question of the data, such as: is the sepal area signficantly different in virginica compared to setosa? Answer the question through both a plot and using a mann-whitney or t-test. If you use a t-test, be sure assumptions are met (independence, normality, equal variance).

# %%
from scipy import stats

# %% [markdown]
# ## is petal area for versicolor significantly different from virginica?

# %%
virg_vers = iris_train[(iris_train.species == 'virginica') | (iris_train.species == 'versicolor')].copy()
virg_vers['petal_area'] = virg_vers.petal_length * virg_vers.petal_width
sns.boxplot(data=virg_vers,x='petal_area',y='species')
# Out:
# <AxesSubplot:xlabel='petal_area', ylabel='species'>

# %% [markdown]
# $H_0$:There is no significant difference in petal area between virginica and versicolor
#
# $H_a$:There is a significant difference in petal area between virginica and versicolor
#
# (*petal area has been simplified to petal length \* petal width for simplicity*)

# %% [markdown]
# ### Assumptions
#
# 1. Independent sample: check
#
# 2. Data is normally distributed
# (Central Limit theorem means we can assume)
#
# 3. equal variance

# %%
virg_area = virg_vers[virg_vers.species == 'virginica'].petal_area
vers_area = virg_vers[virg_vers.species == 'versicolor'].petal_area
stats.levene(virg_area,vers_area)
# Out:
# LeveneResult(statistic=5.492854856101069, pvalue=0.022805255506485003)

# %% [markdown]
# Not of equal variance, but ttest can account for that

# %%
stats.ttest_ind(virg_area,vers_area, equal_var=False)
# Out:
# Ttest_indResult(statistic=11.734382905150175, pvalue=2.8418049208705033e-15)

# %% [markdown]
# We reject the null hypothesis

# %% [markdown]
#     - Document takeaways and any actions.

# %% [markdown]
# Explore your titanic dataset more completely.
#
# Determine drivers of the target variable

# %%
train = titanic_train
target = train['survived']
train.index = train.passenger_id
train.describe()
# Out:
#        passenger_id    survived      pclass       sibsp       parch  \
# count    498.000000  498.000000  498.000000  498.000000  498.000000
# mean     449.459839    0.383534    2.305221    0.495984    0.353414
# std      258.301890    0.486735    0.826627    1.131666    0.763608
# min        0.000000    0.000000    1.000000    0.000000    0.000000
# 25%      221.250000    0.000000    2.000000    0.000000    0.000000
# 50%      453.500000    0.000000    3.000000    0.000000    0.000000
# 75%      675.750000    1.000000    3.000000    1.000000    0.000000
# max      890.000000    1.000000    3.000000    8.000000    5.000000
#
#              fare       alone  sex_female    sex_male  embark_town_Cherbourg  \
# count  498.000000  498.000000  498.000000  498.000000             498.000000
# mean    31.130028    0.632530    0.351406    0.648594               0.204819
# std     47.162206    0.482601    0.477889    0.477889               0.403975
# min      0.000000    0.000000    0.000000    0.000000               0.000000
# 25%      7.895800    0.000000    0.000000    0.000000               0.000000
# 50%     13.500000    1.000000    0.000000    1.000000               0.000000
# 75%     30.392700    1.000000    1.000000    1.000000               0.000000
# max    512.329200    1.000000    1.000000    1.000000               1.000000
#
#        embark_town_Queenstown  embark_town_Southampton
# count              498.000000               498.000000
# mean                 0.082329                 0.710843
# std                  0.275142                 0.453827
# min                  0.000000                 0.000000
# 25%                  0.000000                 0.000000
# 50%                  0.000000                 1.000000
# 75%                  0.000000                 1.000000
# max                  1.000000                 1.000000

# %%
numerics = train.select_dtypes(['float64','int64']).drop(columns=['survived','passenger_id','pclass','alone'])
numerics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 498 entries, 583 to 744
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sibsp   498 non-null    int64
#  1   parch   498 non-null    int64
#  2   fare    498 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 15.6 KB

# %%
i = 1
plt.figure(figsize=(10,20))
for n in numerics:
    plt.subplot(420 + i)
    sns.histplot(data=numerics, x=n)
    plt.subplot(420+i+1)
    sns.boxplot(data=numerics,x=n)
    i += 2
plt.subplot(427)
sns.histplot(data=train.sex_male,bins=2)
plt.subplot(428)
sns.barplot(x=train.alone.unique(), y=train.alone.value_counts())
# Out:
# <AxesSubplot:ylabel='alone'>

# %%
# plt.subplot(4,2,1)
survivors = train[train.survived == 1]
total_count = sns.countplot(data=train,x='sex_male',color='red')
survived_count = sns.countplot(data=survivors,x='sex_male',color='blue')
plt.xlabel('gender')
plt.xticks([0,1],['female','male'])
plt.text(-.3,75,'female survivors: ' + str(survivors.sex_female.sum()))
plt.text(.76,20,'male survivors: ' + str(survivors.sex_male.sum()))
# Out:
# Text(0.76, 20, 'male survivors: 58')

# %%
sns.countplot(data=train,x='pclass',saturation=0)
sns.countplot(data=survivors, x='pclass',saturation = .95)
plt.yticks(np.arange(300, step=25))
# Out:
# ([<matplotlib.axis.YTick at 0x7fac7747a6a0>,
#   <matplotlib.axis.YTick at 0x7fac77478ee0>,
#   <matplotlib.axis.YTick at 0x7fac77478610>,
#   <matplotlib.axis.YTick at 0x7fac7b53a100>,
#   <matplotlib.axis.YTick at 0x7fac77305400>,
#   <matplotlib.axis.YTick at 0x7fac7b53a3a0>,
#   <matplotlib.axis.YTick at 0x7fac7b540100>,
#   <matplotlib.axis.YTick at 0x7fac7b540850>,
#   <matplotlib.axis.YTick at 0x7fac7b546070>,
#   <matplotlib.axis.YTick at 0x7fac7b546730>,
#   <matplotlib.axis.YTick at 0x7fac7b546e80>,
#   <matplotlib.axis.YTick at 0x7fac7b546820>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sns.swarmplot(data=train,x='survived',y='fare')
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 59.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 30.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
sns.pairplot(data=numerics)

# %% [markdown]
# ## takeaways
# parch is, like, all outliers
# fare has a lot of outliers too. Not bad but weird
# sibsp is also problematic

# %% [markdown]
# Determine if certain columns should be dropped

# %% [markdown]
# Determine if it would be valuable to bin some numeric columns

# %% [markdown]
# Determine if it would be valuable to combine multiple columns into one.

# %% [markdown]
# Does it make sense to combine any features?

# %% [markdown]
# Do you find any surprises?

# %% [markdown]
# Document any and all findings and takeaways in your notebook using markdown.
